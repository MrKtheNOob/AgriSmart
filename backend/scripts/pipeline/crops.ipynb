# %%
import pandas as pd
df=pd.read_json("./crops_simplified.json")

# %%
df.head()
# Out:
#   schema_version                                               crop  \
# 0          0.1.0  {'id': 'maize', 'common_name': 'Maize', 'scien...
# 1          0.1.0  {'id': 'millet_pearl', 'common_name': 'Millet'...
# 2          0.1.0  {'id': 'tomato', 'common_name': 'Tomato', 'sci...
# 3          0.1.0  {'id': 'onion', 'common_name': 'Onion', 'scien...
# 4          0.1.0  {'id': 'groundnut', 'common_name': 'Groundnut'...
#
#                                         requirements  \
# 0  {'soil': {'ph': {'optimal': {'minimum': 5.0, '...
# 1  {'soil': {'ph': {'optimal': {'minimum': 5.0, '...
# 2  {'soil': {'ph': {'optimal': {'minimum': 5.5, '...
# 3  {'soil': {'ph': {'optimal': {'minimum': 6.0, '...
# 4  {'soil': {'ph': {'optimal': {'minimum': 5.5, '...
#
#                                              sources  \
# 0  [{'id': 'source_baseline', 'title': 'crops_sim...
# 1  [{'id': 'source_baseline', 'title': 'crops_sim...
# 2  [{'id': 'source_baseline', 'title': 'crops_sim...
# ...

# %%
import json
crops=df["crop"]
#id common_name scientific_name
# Out:
# {'id': 'millet_pearl',
#  'common_name': 'Millet',
#  'scientific_name': 'Pennisetum glaucum (L.) R.Br.'}

# %%
import json
json.loads(crops)
